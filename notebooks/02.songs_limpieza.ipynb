# %% [markdown]
# # Limpieza y Transformación de datos
#
# - id -> Pasar a minusculas
# - name -> Pasar a minusculas. Eliminar exclamaciones, tanto al principio como al final de palabra, como solo la exclamacion como texto.
# - album_name -> Pasar a minusculas. Algunas palabras contienen una exclamacion en medio como (UNDEN!ABLE)
# - artists -> Pasar a minusculas. Eliminar comillas “” y corchetes []. Tambien hay \ en medio de palabras. Seguramente genere nulos.
# - lyrics -> La eliminaria.
# - artist_ids -> Pasar a minusculas. Eliminar comillas “” y corchetes []. Seguramente genere nulos
# - niche_genres -> Eliminar comillas “” y corchetes []. Seguramente genere nulos. Además, veo mas de una categoría para la misma fila.
# - year: podrías crear columna decade = year // 10 * 10 para análisis por décadas

# %%
#Tratamiento de datos
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

#Exploracion de archivos
import sys
sys.path.append('../')

#Funciones personalizadas
from src import soporte_limpieza as spl

# %%
df_o = pd.read_csv("../data/raw/songs.csv")

# %%
df = df_o.copy()

# %%
# Columnas a eliminar porque no aportan mucho para el análisis
columns_to_drop = [
    "danceability", "energy", "loudness", "speechiness", 
    "acousticness", "instrumentalness", "liveness", "valence"
]

# Aplicar limpieza usando el soporte
df = spl.clean_songs(df, drop_columns=columns_to_drop)

# %%
df.head(5)
# Out:
#                        id             name           album_name  \
# 0  0prct5tdjanegiqbxcldy9                            unden!able
# 1  2asl4wirkeym3owzxxkyuq                      childhood dreams
# 2  5ta3imw310llko8embj2ga  noble stabbings  situationist comedy
# 3  0frot4kk5otm8xo8px6ejf      ill be back       !i'll be back!
# 4  1xbfhv5faebv3mmwxx7dns             lost               !lost!
#
#             artists  key   mode    tempo  duration_ms    genre  popularity  \
# 0        [hellyeah]    7  major  100.059        79500     rock           0
# 1         [yxngxr1]    7  minor   79.998       114000  hip-hop          29
# 2  [dillinger four]    2  major  175.317       197400     rock           0
# 3           [rilès]    1  major  142.959       178533  hip-hop          43
# 4           [rilès]    7  minor   86.103       186197  hip-hop           0
#
#    total_artist_followers  avg_artist_popularity                artist_ids  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 550622 entries, 0 to 550621
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   id                      550622 non-null  str
#  1   name                    550618 non-null  str
#  2   album_name              550602 non-null  str
#  3   artists                 550622 non-null  object
#  4   key                     550622 non-null  int64
#  5   mode                    550622 non-null  str
#  6   tempo                   550622 non-null  float64
#  7   duration_ms             550622 non-null  int64
#  8   genre                   550622 non-null  str
#  9   popularity              550622 non-null  int64
#  10  total_artist_followers  550622 non-null  int64
#  11  avg_artist_popularity   550622 non-null  float64
#  12  artist_ids              550622 non-null  object
#  13  niche_genres            550622 non-null  object
# ...
